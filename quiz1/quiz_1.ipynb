# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread(r"C:\Users\Asus\Downloads\avc-mpg-face-shaving-tips-stages-sp.jpg")
plt.imshow(img[:,:,::-1])

# %%
cropped_img = img[:610, 210:650]
plt.imshow(cropped_img[:,:,::-1])

# %%
cv.imwrite("Cropped.jpg", img)
# Out:
# True
