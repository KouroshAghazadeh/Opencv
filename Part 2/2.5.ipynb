# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
alpha_slider_max = 100
title_window = 'Linear Blend'

def on_trackbar(val):
    alpha = val/alpha_slider_max
    beta = (1 - alpha)
    dst = cv.addWeighted(src1, alpha, src2, beta, 0.0)
    cv.imshow(title_window, dst)
    
src1 = cv.imread("D:\Opencv\class.vision-master\images\class.vision.jpg")
src2 = cv.imread("D:\Opencv\class.vision-master\images\opencv.jpg")

cv.namedWindow(title_window)
trackbar_name = 'alpha'
cv.createTrackbar(trackbar_name, title_window, 0, alpha_slider_max, on_trackbar)

on_trackbar(0)

cv.waitKey()
cv.destroyAllWindows()

# %%
alpha_slider_max = 100
title_window = 'Linear Blend'

def on_trackbar(val):
    global dst, alpha
    
    alpha = val/alpha_slider_max
    beta = (1 - alpha)
    dst = cv.addWeighted(src1, alpha, src2, beta, 0.0)
    cv.imshow(title_window, dst)
    
src1 = cv.imread("D:\Opencv\class.vision-master\images\class.vision.jpg")
src2 = cv.imread("D:\Opencv\class.vision-master\images\opencv.jpg")

cv.namedWindow(title_window)
trackbar_name = 'alpha'
cv.createTrackbar(trackbar_name, title_window, 0, alpha_slider_max, on_trackbar)

on_trackbar(0)

cv.waitKey()
cv.destroyAllWindows()

plt.imshow(dst[...,::-1])
print("alpha:{}".format(alpha))
# Out:
# alpha:0.43

# %%
def nothing(x):
    pass

img = np.zeros((300, 512, 3), 'uint8')
cv.namedWindow('image')
cv.createTrackbar('R', 'image', 0, 255, nothing)
cv.createTrackbar('G', 'image', 0, 255, nothing)
cv.createTrackbar('B', 'image', 0, 255, nothing)

switch = "OFF:ON"
cv.createTrackbar(switch, 'image', 0, 1, nothing)

while True:
    cv.imshow('image', img)
    if cv.waitKey(1) & 0xFF == 27:
        break
        
    r = cv.getTrackbarPos('R', 'image')
    g = cv.getTrackbarPos('G', 'image')
    b = cv.getTrackbarPos('B', 'image')
    s = cv.getTrackbarPos(switch, 'image')
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]
cv.destroyAllWindows()
