# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\blob.jpg")

detector = cv.SimpleBlobDetector_create()

keypoints = detector.detect(image)

result1 = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255))
result2 = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Image")
plt.subplot(132);plt.imshow(result1[...,::-1]);plt.title("Result1")
plt.subplot(133);plt.imshow(result2[...,::-1]);plt.title("Result2")
# Out:
# Text(0.5, 1.0, 'Result2')

# %%
for k in keypoints:
    print("Point: ", k.pt)
    print("Size: ", k.size)
# Out:
# Point:  (133.01858520507812, 43.01858901977539)
# Size:  48.077266693115234
# Point:  (187.0471649169922, 112.04715728759766)
# Size:  63.91517639160156
# Point:  (57.01155471801758, 158.0416259765625)
# Size:  75.37721252441406
# Point:  (45.0250244140625, 47.0250244140625)
# Size:  50.042076110839844
# Point:  (167.02386474609375, 194.0207977294922)
# Size:  57.99103546142578

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\blob_size.jpg")
params = cv.SimpleBlobDetector_Params()
params.filterByArea = True
params.minArea = 5000
params.maxArea = 20000

detector = cv.SimpleBlobDetector_create(params)

keypoints = detector.detect(image)

result = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(result[...,::-1])

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\blob_Circularity.jpg")

params = cv.SimpleBlobDetector_Params()
params.filterByCircularity = True
params.minCircularity = 0.84

detector = cv.SimpleBlobDetector_create(params)

keypoints = detector.detect(image)

result = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(result[...,::-1])

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\blob_convexity.jpg")

params = cv.SimpleBlobDetector_Params()
params.filterByConvexity = True
params.minConvexity = 0.85

detector = cv.SimpleBlobDetector_create(params)

keypoints = detector.detect(image)

result = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(result[...,::-1])

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\blob_inertia.jpg")

params = cv.SimpleBlobDetector_Params()
params.filterByInertia = True
params.minInertiaRatio = 0.3
params.maxInertiaRatio = 0.7
detector = cv.SimpleBlobDetector_create(params)

keypoints = detector.detect(image)

result = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(result[...,::-1])

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\blob_Threshold.jpg")

params = cv.SimpleBlobDetector_Params()
params.maxThreshold = 150

detector = cv.SimpleBlobDetector_create(params)

keypoints = detector.detect(image)

result = cv.drawKeypoints(image, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(result[...,::-1])
