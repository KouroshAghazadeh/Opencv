# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\old-iranian-coins.jpg")
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

thresh = cv.adaptiveThreshold(gray, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((5, 5), np.uint8)
closing = cv.morphologyEx(thresh, cv.MORPH_CLOSE, kernel)

contours, hierchery = cv.findContours(closing, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
drawing_image = image.copy()

for cnt in contours:
    if len(cnt) < 5:
        continue
    ellipse = cv.fitEllipse(cnt)
    cv.ellipse(drawing_image, ellipse, (0,255,0), 2)
    
plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original")
plt.subplot(132);plt.imshow(closing, cmap='gray');plt.title("closing")
plt.subplot(133);plt.imshow(drawing_image[...,::-1]);plt.title("Result")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 16
#      14         continue
#      15     ellipse = cv.fitEllipse(cnt)
# ---> 16     cv.ellipse(drawing_image, ellipse, (0,255,0), 2)
#      18 plt.figure(figsize=[15,15])
#      19 plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original")
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\drawing.cpp:1983: error: (-215:Assertion failed) box.size.width >= 0 && box.size.height >= 0 && thickness <= MAX_THICKNESS in function 'cv::ellipse'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
image = cv2.imread(r"D:\Opencv\class.vision-master\images\old-iranian-coins.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_blur = cv2.GaussianBlur(gray, (31, 31), 0) #Noise removal
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((5, 5), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
        
contours, hierarchy = cv2.findContours(closing, cv2.RETR_EXTERNAL,
                                       cv2.CHAIN_APPROX_SIMPLE)
        
drawing_image = image.copy()
for cnt in contours:
    if len(cnt) < 5: #There should be at least 5 points to fit the ellipse in function 'fitEllipse'
        continue
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(drawing_image, ellipse, (0,255,0), 2)

plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original");
plt.subplot(132);plt.imshow(closing, cmap='gray');plt.title("closing");
plt.subplot(133);plt.imshow(drawing_image[...,::-1]);plt.title("result");
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 22
#      20         continue
#      21     ellipse = cv2.fitEllipse(cnt)
# ---> 22     cv2.ellipse(drawing_image, ellipse, (0,255,0), 2)
#      24 plt.figure(figsize=[15,15])
#      25 plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original");
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\drawing.cpp:1983: error: (-215:Assertion failed) box.size.width >= 0 && box.size.height >= 0 && thickness <= MAX_THICKNESS in function 'cv::ellipse'

# %%
image = cv2.imread(r"D:\Opencv\class.vision-master\images\old-iranian-coins.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_blur = cv2.GaussianBlur(gray, (31, 31), 0) #Noise removal
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((5, 5), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
        
contours, hierarchy = cv2.findContours(closing, cv2.RETR_EXTERNAL,
                                       cv2.CHAIN_APPROX_SIMPLE)
        
drawing_image = image.copy()
for cnt in contours:
    if len(cnt) < 100: #100 is more probable to be a circle!
        continue
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(drawing_image, ellipse, (0,255,0), 2)

plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original");
plt.subplot(132);plt.imshow(closing, cmap='gray');plt.title("closing");
plt.subplot(133);plt.imshow(drawing_image[...,::-1]);plt.title("result");

# %%
image = cv2.imread(r"D:\Opencv\class.vision-master\images\old-iranian-coins.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_blur = cv2.GaussianBlur(gray, (31, 31), 0) #Noise removal
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((5, 5), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
        
contours, hierarchy = cv2.findContours(closing, cv2.RETR_EXTERNAL,
                                       cv2.CHAIN_APPROX_SIMPLE)
        
drawing_image = image.copy()
for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 5000 or area > 50000:
        continue

    if len(cnt) < 5:
        continue

    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(drawing_image, ellipse, (0,255,0), 2)

plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original");
plt.subplot(132);plt.imshow(closing, cmap='gray');plt.title("closing");
plt.subplot(133);plt.imshow(drawing_image[...,::-1]);plt.title("result");
