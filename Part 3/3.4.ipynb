# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread("D:\Opencv\class.vision-master\images\opencv_inv.png", 0)

kernel = np.ones((5,5), 'uint8')

erosion = cv.erode(image, kernel, iterations = 1)
dilation = cv.dilate(image, kernel, iterations = 1)
opening = cv.morphologyEx(image, cv.MORPH_OPEN, kernel)
closing = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)

plt.figure(figsize=[10,8])
plt.subplot(321);plt.imshow(image, cmap='gray');plt.title("Original")

plt.subplot(323);plt.imshow(erosion, cmap='gray');plt.title("Erosion")
plt.subplot(324);plt.imshow(dilation, cmap='gray');plt.title("Dilation")

plt.subplot(325);plt.imshow(opening, cmap='gray');plt.title("Opening")
plt.subplot(326);plt.imshow(closing, cmap='gray');plt.title("Closing")
# Out:
# Text(0.5, 1.0, 'Closing')

# %%
subtracted = cv.subtract(dilation, erosion)
plt.imshow(subtracted, cmap='gray')

# %%
image = cv.imread("D:\Opencv\class.vision-master\images\opencv_inv.png", 0)

kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5,5), (2,2))

erosion = cv.erode(image, kernel, iterations = 1)
dilation = cv.dilate(image, kernel, iterations = 1)
opening = cv.morphologyEx(image, cv.MORPH_OPEN, kernel)
closing = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)

plt.figure(figsize=[10,8])
plt.subplot(321);plt.imshow(image, cmap='gray');plt.title("Original")

plt.subplot(323);plt.imshow(erosion, cmap='gray');plt.title("Erosion")
plt.subplot(324);plt.imshow(dilation, cmap='gray');plt.title("Dilation")

plt.subplot(325);plt.imshow(opening, cmap='gray');plt.title("Opening")
plt.subplot(326);plt.imshow(closing, cmap='gray');plt.title("Closing")
# Out:
# Text(0.5, 1.0, 'Closing')

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\Opening.png", 0)

kernel = np.ones((5,5), 'uint8')

opening = cv.morphologyEx(image, cv.MORPH_OPEN, kernel)

plt.figure(figsize=[8,5])
plt.subplot(121);plt.imshow(image, cmap='gray');plt.title("Original")
plt.subplot(122);plt.imshow(opening, cmap='gray');plt.title("Opening")
# Out:
# Text(0.5, 1.0, 'Opening')

# %%
image = cv.imread(r"D:\Opencv\class.vision-master\images\closing.png", 0)

kernel = np.ones((5,5), 'uint8')

closing = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)

plt.figure(figsize=[8,5])
plt.subplot(121);plt.imshow(image, cmap='gray');plt.title("Original")
plt.subplot(122);plt.imshow(closing, cmap='gray');plt.title("Closing")
# Out:
# Text(0.5, 1.0, 'Closing')
