# %%
import cv2 as cv
import numpy as np

# %%
img = cv.imread("D:\Opencv\class.vision-master\images\input.jpg")
cv.imshow("it is cow", img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (600, 800, 3)

# %%
print("Height of image: ", int(img.shape[0]),'pixels')
print("Weight of image: ", int(img.shape[1]),'pixels')
# Out:
# Height of image:  600 pixels
# Weight of image:  800 pixels

# %%
cv.imwrite("output.jpg", img)
# Out:
# True

# %%
cv.imwrite("output.png", img)
# Out:
# True

# %% [markdown]
# ---------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,::-1])

# %%
rgb_image = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
rgb_image[200:300, 300:500, :] = (200, 255, 150)
plt.imshow(rgb_image)
