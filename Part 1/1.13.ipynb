# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img_original = cv.imread(r"D:\Opencv\class.vision-master\images\room-light.jpg", cv.IMREAD_UNCHANGED)
lookUpTable = np.empty((1,256), np.uint8)

for i in range(256):
    lookUpTable[0,i] = np.clip(pow(i / 255.0, gamma) * 255.0, 0, 255)
out = cv.LUT(img_original, lookUpTable)


plt.figure(figsize=[15,5])
plt.subplot(121);plt.imshow(img_original[...,::-1]);plt.title("Original");
plt.subplot(122);plt.imshow(out[...,::-1]);plt.title("Output");
